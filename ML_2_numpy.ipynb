# %% [markdown]
# <a href="https://colab.research.google.com/github/PARTHDEVX2904/MACHINE_LEARNING/blob/main/ML_2_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #                      **NUMPY PRACTICE**

# %%
import numpy as np

# %%
a = np.array([[1, 2, 3],
              [4, 5, 6]])
# a.shape
# (2, 3)
print(a)
# Out:
# [[1 2 3]
#  [4 5 6]]
